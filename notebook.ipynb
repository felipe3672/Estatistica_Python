# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_11104\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# df = pd.read_csv(r"C:\Users\Felipe\Downloads\arquivo alura.csv")
array = np.loadtxt(r"C:\Users\Felipe\Downloads\Curso_alura_estatistica\arquivo alura.csv", delimiter = ',', usecols=np.arange(1,88,1))

# %%
#verifica as dimensoes do array
print('dimensões do array: ' + str(array.ndim))
#verificar o tamanho
print('tamanho do array: ' + str(array.size))
#estrutura do array
print('tamanho do array: ' + str(array.shape))
# Out:
# dimensões do array: 2
# tamanho do array: 522
# tamanho do array: (6, 87)

# %%
#transposição
transpose = array.T

# %%
datas = transpose[:,0]

# %%
p = transpose[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88,1)

# %%
plt.plot(datas, p[:,0])
plt.show()

# %%
Moscow = np.array(p[:,0])
Kaliningrad = np.array(p[:,1])
Petersburg = np.array(p[:,2])
Krasnodar = np.array(p[:,3])
Ekaterinburg = np.array(p[:,4])

# %%
moscow_1 = Moscow[0:12]
moscow_2 = Moscow[13:25]
moscow_3 = Moscow[25:37]
moscow_4 = Moscow[37:49]

# %%
plt.plot(np.arange(1,13,1), moscow_1)
plt.plot(np.arange(1,13,1), moscow_2)
plt.plot(np.arange(1,13,1), moscow_3)
plt.plot(np.arange(1,13,1), moscow_4)
plt.legend(['ano_1','ano_2','ano_3','ano_4'])

# %%
# para saber se nos dados tem alguma correlação no caso aqui de queda
np.array_equal(moscow_3,moscow_4)
# Out:
# False

# %%
#verifica se o arrays são próximos dentro de um certo intervalo
np.allclose(moscow_3,moscow_4,4000)
# Out:
# True

# %%
plt.plot(datas, Kaliningrad)

# %%
sum ( np.isnan(Kaliningrad))
# Out:
# 1

# %%
Kaliningrad[4] =  np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
print(np.mean(Moscow))
print(np.mean(Kaliningrad))
# Out:
# 98.79781609195402
# 74.5506896551724

# %%
x = datas
y =  2*x+80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
# np.power(Moscow-y,2)
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 749.2329171225728

# %%
y =  0.52*x+80

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
#normalização de dados
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %%
y = Moscow
x = datas
n = np.size(Moscow)

# %%
a = (n*np.sum(x*y) - np.sum(x) * np.sum(y))/(n * np.sum(x**2) - np.sum(x)**2)

# %%
b = np.mean(y) - a*np.mean(x)

# %%
c = a*x+b

# %%
np.linalg.norm(Moscow - c)
# Out:
# 101.7969539992751

# %%
plt.plot(datas,Moscow)
plt.plot(x,c)
plt.plot(41.5,41.5*a+b,'*r')
plt.plot(100,100*a+b,'*r')
